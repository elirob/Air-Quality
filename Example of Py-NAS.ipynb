# %%
import aq_functions.openfunctions as opf
import aq_functions.aq_plot as aq_plot

# %matplotlib inline

# %%
test_file = r'../Ebas_150116_1110/GB0046R.20030107080000.20040302000000.low_vol_sampler.pm10_mass.pm10.6mo.1w.NO01L_lvs_uk17.NO01L_Thermo_Optical-Sunset_Lab.lev2.nas'

# %%
aq_plot.nice_fill_plot(test_file)

# %%
our_frame = opf.data_to_pandas_dataframe(test_file)

# %%
our_frame.describe()
# Out:
#        pm10_mass
# count  25.000000
# mean   18.286800
# std    18.431268
# min     3.420000
# 25%     7.610000
# 50%    11.870000
# 75%    16.680000
# max    77.730000

# %%
aq_plot.timeseries_histogram_simple(our_frame)
